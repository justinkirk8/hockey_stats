# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import requests
from pprint import pprint

# %%
#basic call for standings for a given season
# "https://statsapi.web.nhl.com/api/v1/standings"
#indicates what season we want. format year start year end
season=""
# exanded variable required for win loss tally
# &expand=standings.record

query_url= f"https://statsapi.web.nhl.com/api/v1/standings?expand=standings.record{season}"
query_url
# Out:
# 'https://statsapi.web.nhl.com/api/v1/standings?expand=standings.record'

# %%
#request data from API
hockey_response = requests.get(query_url)
hockey_response
# Out:
# <Response [200]>

# %%
hockey_json = hockey_response.json()
pprint(hockey_json)
# Out:
# {'copyright': 'NHL and the NHL Shield are registered trademarks of the '
#               'National Hockey League. NHL and NHL team marks are the property '
#               'of the NHL and its teams. © NHL 2022. All Rights Reserved.',
#  'records': [{'conference': {'id': 6,
#                              'link': '/api/v1/conferences/6',
#                              'name': 'Eastern'},
#               'division': {'abbreviation': 'M',
#                            'id': 18,
#                            'link': '/api/v1/divisions/18',
#                            'name': 'Metropolitan',
#                            'nameShort': 'Metro'},
#               'league': {'id': 133,
#                          'link': '/api/v1/league/133',
#                          'name': 'National Hockey League'},
#               'standingsType': 'regularSeason',
#               'teamRecords': [{'conferenceHomeRank': '2',
#                                'conferenceL10Rank': '8',
#                                'conferenceRank': '2',
#                                'conferenceRoadRank': '7',
#                                'divisionHomeRank': '1',
#                                'divisionL10Rank': '4',
#                                'divisionRank': '1',
#                                'divisionRoadRank': '4',
#                                'gamesPlayed': 69,
#                                'goalsAgainst': 164,
#                                'goalsScored': 230,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '3',
#                                'leagueL10Rank': '19',
#                                'leagueRank': '3',
#                                'leagueRecord': {'losses': 16,
#                                                 'ot': 8,
#                                                 'type': 'league',
#                                                 'wins': 45},
#                                'leagueRoadRank': '9',
#                                'points': 98,
#                                'pointsPercentage': 0.7101449275362319,
#                                'ppConferenceRank': '2',
#                                'ppDivisionRank': '1',
#                                'ppLeagueRank': '3',
#                                'records': {'conferenceRecords': [{'losses': 11,
#                                                                   'ot': 6,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 24},
#                                                                  {'losses': 5,
#                                                                   'ot': 2,
#                                                                   'type': 'Western',
#                                                                   'wins': 21}],
#                                            'divisionRecords': [{'losses': 3,
#                                                                 'ot': 1,
#                                                                 'type': 'Central',
#                                                                 'wins': 9},
#                                                                {'losses': 4,
#                                                                 'ot': 5,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 12},
#                                                                {'losses': 2,
#                                                                 'ot': 1,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 12},
#                                                                {'losses': 7,
#                                                                 'ot': 1,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 12}],
#                                            'overallRecords': [{'losses': 6,
#                                                                'ot': 4,
#                                                                'type': 'home',
#                                                                'wins': 25},
#                                                               {'losses': 10,
#                                                                'ot': 4,
#                                                                'type': 'away',
#                                                                'wins': 20},
#                                                               {'losses': 2,
#                                                                'type': 'shootOuts',
#                                                                'wins': 1},
#                                                               {'losses': 3,
#                                                                'ot': 3,
#                                                                'type': 'lastTen',
#                                                                'wins': 4}]},
#                                'regulationWins': 39,
#                                'row': 44,
#                                'streak': {'streakCode': 'L1',
#                                           'streakNumber': 1,
#                                           'streakType': 'losses'},
#                                'team': {'id': 12,
#                                         'link': '/api/v1/teams/12',
#                                         'name': 'Carolina Hurricanes'},
#                                'wildCardRank': '0'},
#                               {'conferenceHomeRank': '4',
#                                'conferenceL10Rank': '5',
#                                'conferenceRank': '4',
#                                'conferenceRoadRank': '6',
#                                'divisionHomeRank': '2',
#                                'divisionL10Rank': '2',
#                                'divisionRank': '2',
#                                'divisionRoadRank': '3',
#                                'gamesPlayed': 70,
#                                'goalsAgainst': 185,
#                                'goalsScored': 214,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '7',
#                                'leagueL10Rank': '10',
#                                'leagueRank': '5',
#                                'leagueRecord': {'losses': 20,
#                                                 'ot': 6,
#                                                 'type': 'league',
#                                                 'wins': 44},
#                                'leagueRoadRank': '7',
#                                'points': 94,
#                                'pointsPercentage': 0.6714285714285714,
#                                'ppConferenceRank': '6',
#                                'ppDivisionRank': '2',
#                                'ppLeagueRank': '7',
#                                'records': {'conferenceRecords': [{'losses': 9,
#                                                                   'ot': 2,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 28},
#                                                                  {'losses': 11,
#                                                                   'ot': 4,
#                                                                   'type': 'Western',
#                                                                   'wins': 16}],
#                                            'divisionRecords': [{'losses': 6,
#                                                                 'ot': 1,
#                                                                 'type': 'Central',
#                                                                 'wins': 8},
#                                                                {'losses': 2,
#                                                                 'ot': 1,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 17},
#                                                                {'losses': 5,
#                                                                 'ot': 3,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 8},
#                                                                {'losses': 7,
#                                                                 'ot': 1,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 11}],
#                                            'overallRecords': [{'losses': 7,
#                                                                'ot': 4,
#                                                                'type': 'home',
#                                                                'wins': 22},
#                                                               {'losses': 13,
#                                                                'ot': 2,
#                                                                'type': 'away',
#                                                                'wins': 22},
#                                                               {'losses': 3,
#                                                                'type': 'shootOuts',
#                                                                'wins': 4},
#                                                               {'losses': 3,
#                                                                'ot': 1,
#                                                                'type': 'lastTen',
#                                                                'wins': 6}]},
#                                'regulationWins': 36,
#                                'row': 40,
#                                'streak': {'streakCode': 'OT1',
#                                           'streakNumber': 1,
#                                           'streakType': 'ot'},
#                                'team': {'id': 3,
#                                         'link': '/api/v1/teams/3',
#                                         'name': 'New York Rangers'},
#                                'wildCardRank': '0'},
#                               {'conferenceHomeRank': '7',
#                                'conferenceL10Rank': '10',
#                                'conferenceRank': '7',
#                                'conferenceRoadRank': '1',
#                                'divisionHomeRank': '3',
#                                'divisionL10Rank': '5',
#                                'divisionRank': '3',
#                                'divisionRoadRank': '1',
#                                'gamesPlayed': 70,
#                                'goalsAgainst': 188,
#                                'goalsScored': 233,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '13',
#                                'leagueL10Rank': '21',
#                                'leagueRank': '8',
#                                'leagueRecord': {'losses': 19,
#                                                 'ot': 10,
#                                                 'type': 'league',
#                                                 'wins': 41},
#                                'leagueRoadRank': '1',
#                                'points': 92,
#                                'pointsPercentage': 0.6571428571428571,
#                                'ppConferenceRank': '7',
#                                'ppDivisionRank': '3',
#                                'ppLeagueRank': '10',
#                                'records': {'conferenceRecords': [{'losses': 12,
#                                                                   'ot': 5,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 24},
#                                                                  {'losses': 7,
#                                                                   'ot': 5,
#                                                                   'type': 'Western',
#                                                                   'wins': 17}],
#                                            'divisionRecords': [{'losses': 3,
#                                                                 'ot': 3,
#                                                                 'type': 'Central',
#                                                                 'wins': 8},
#                                                                {'losses': 6,
#                                                                 'ot': 3,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 12},
#                                                                {'losses': 4,
#                                                                 'ot': 2,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 9},
#                                                                {'losses': 6,
#                                                                 'ot': 2,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 12}],
#                                            'overallRecords': [{'losses': 10,
#                                                                'ot': 5,
#                                                                'type': 'home',
#                                                                'wins': 19},
#                                                               {'losses': 9,
#                                                                'ot': 5,
#                                                                'type': 'away',
#                                                                'wins': 22},
#                                                               {'losses': 6,
#                                                                'type': 'shootOuts',
#                                                                'wins': 3},
#                                                               {'losses': 4,
#                                                                'ot': 1,
#                                                                'type': 'lastTen',
#                                                                'wins': 5}]},
#                                'regulationWins': 33,
#                                'row': 38,
#                                'streak': {'streakCode': 'L1',
#                                           'streakNumber': 1,
#                                           'streakType': 'losses'},
#                                'team': {'id': 5,
#                                         'link': '/api/v1/teams/5',
#                                         'name': 'Pittsburgh Penguins'},
#                                'wildCardRank': '0'},
#                               {'conferenceHomeRank': '11',
#                                'conferenceL10Rank': '7',
#                                'conferenceRank': '8',
#                                'conferenceRoadRank': '2',
#                                'divisionHomeRank': '6',
#                                'divisionL10Rank': '3',
#                                'divisionRank': '4',
#                                'divisionRoadRank': '2',
#                                'gamesPlayed': 69,
#                                'goalsAgainst': 202,
#                                'goalsScored': 226,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '21',
#                                'leagueL10Rank': '17',
#                                'leagueRank': '14',
#                                'leagueRecord': {'losses': 22,
#                                                 'ot': 10,
#                                                 'type': 'league',
#                                                 'wins': 37},
#                                'leagueRoadRank': '2',
#                                'points': 84,
#                                'pointsPercentage': 0.6086956521739131,
#                                'ppConferenceRank': '8',
#                                'ppDivisionRank': '4',
#                                'ppLeagueRank': '12',
#                                'records': {'conferenceRecords': [{'losses': 12,
#                                                                   'ot': 4,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 24},
#                                                                  {'losses': 10,
#                                                                   'ot': 6,
#                                                                   'type': 'Western',
#                                                                   'wins': 13}],
#                                            'divisionRecords': [{'losses': 4,
#                                                                 'ot': 3,
#                                                                 'type': 'Central',
#                                                                 'wins': 7},
#                                                                {'losses': 6,
#                                                                 'ot': 3,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 10},
#                                                                {'losses': 6,
#                                                                 'ot': 3,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 6},
#                                                                {'losses': 6,
#                                                                 'ot': 1,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 14}],
#                                            'overallRecords': [{'losses': 15,
#                                                                'ot': 5,
#                                                                'type': 'home',
#                                                                'wins': 16},
#                                                               {'losses': 7,
#                                                                'ot': 5,
#                                                                'type': 'away',
#                                                                'wins': 21},
#                                                               {'losses': 2,
#                                                                'type': 'shootOuts',
#                                                                'wins': 5},
#                                                               {'losses': 4,
#                                                                'ot': 0,
#                                                                'type': 'lastTen',
#                                                                'wins': 6}]},
#                                'regulationWins': 28,
#                                'row': 32,
#                                'streak': {'streakCode': 'L2',
#                                           'streakNumber': 2,
#                                           'streakType': 'losses'},
#                                'team': {'id': 15,
#                                         'link': '/api/v1/teams/15',
#                                         'name': 'Washington Capitals'},
#                                'wildCardRank': '2'},
#                               {'conferenceHomeRank': '8',
#                                'conferenceL10Rank': '4',
#                                'conferenceRank': '9',
#                                'conferenceRoadRank': '9',
#                                'divisionHomeRank': '4',
#                                'divisionL10Rank': '1',
#                                'divisionRank': '5',
#                                'divisionRoadRank': '5',
#                                'gamesPlayed': 68,
#                                'goalsAgainst': 186,
#                                'goalsScored': 190,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '16',
#                                'leagueL10Rank': '7',
#                                'leagueRank': '20',
#                                'leagueRecord': {'losses': 27,
#                                                 'ot': 9,
#                                                 'type': 'league',
#                                                 'wins': 32},
#                                'leagueRoadRank': '20',
#                                'points': 73,
#                                'pointsPercentage': 0.5367647058823529,
#                                'ppConferenceRank': '9',
#                                'ppDivisionRank': '5',
#                                'ppLeagueRank': '19',
#                                'records': {'conferenceRecords': [{'losses': 15,
#                                                                   'ot': 4,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 19},
#                                                                  {'losses': 12,
#                                                                   'ot': 5,
#                                                                   'type': 'Western',
#                                                                   'wins': 13}],
#                                            'divisionRecords': [{'losses': 5,
#                                                                 'ot': 2,
#                                                                 'type': 'Central',
#                                                                 'wins': 7},
#                                                                {'losses': 9,
#                                                                 'ot': 2,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 8},
#                                                                {'losses': 7,
#                                                                 'ot': 3,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 6},
#                                                                {'losses': 6,
#                                                                 'ot': 2,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 11}],
#                                            'overallRecords': [{'losses': 13,
#                                                                'ot': 4,
#                                                                'type': 'home',
#                                                                'wins': 18},
#                                                               {'losses': 14,
#                                                                'ot': 5,
#                                                                'type': 'away',
#                                                                'wins': 14},
#                                                               {'losses': 6,
#                                                                'type': 'shootOuts',
#                                                                'wins': 1},
#                                                               {'losses': 3,
#                                                                'ot': 0,
#                                                                'type': 'lastTen',
#                                                                'wins': 7}]},
#                                'regulationWins': 30,
#                                'row': 31,
#                                'streak': {'streakCode': 'W4',
#                                           'streakNumber': 4,
#                                           'streakType': 'wins'},
#                                'team': {'id': 2,
#                                         'link': '/api/v1/teams/2',
#                                         'name': 'New York Islanders'},
#                                'wildCardRank': '3'},
#                               {'conferenceHomeRank': '9',
#                                'conferenceL10Rank': '14',
#                                'conferenceRank': '10',
#                                'conferenceRoadRank': '10',
#                                'divisionHomeRank': '5',
#                                'divisionL10Rank': '7',
#                                'divisionRank': '6',
#                                'divisionRoadRank': '6',
#                                'gamesPlayed': 70,
#                                'goalsAgainst': 263,
#                                'goalsScored': 225,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '18',
#                                'leagueL10Rank': '27',
#                                'leagueRank': '21',
#                                'leagueRecord': {'losses': 32,
#                                                 'ot': 6,
#                                                 'type': 'league',
#                                                 'wins': 32},
#                                'leagueRoadRank': '24',
#                                'points': 70,
#                                'pointsPercentage': 0.5,
#                                'ppConferenceRank': '10',
#                                'ppDivisionRank': '6',
#                                'ppLeagueRank': '21',
#                                'records': {'conferenceRecords': [{'losses': 23,
#                                                                   'ot': 2,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 17},
#                                                                  {'losses': 9,
#                                                                   'ot': 4,
#                                                                   'type': 'Western',
#                                                                   'wins': 15}],
#                                            'divisionRecords': [{'losses': 4,
#                                                                 'ot': 2,
#                                                                 'type': 'Central',
#                                                                 'wins': 10},
#                                                                {'losses': 8,
#                                                                 'ot': 2,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 9},
#                                                                {'losses': 5,
#                                                                 'ot': 2,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 5},
#                                                                {'losses': 15,
#                                                                 'ot': 0,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 8}],
#                                            'overallRecords': [{'losses': 14,
#                                                                'ot': 4,
#                                                                'type': 'home',
#                                                                'wins': 18},
#                                                               {'losses': 18,
#                                                                'ot': 2,
#                                                                'type': 'away',
#                                                                'wins': 14},
#                                                               {'losses': 2,
#                                                                'type': 'shootOuts',
#                                                                'wins': 4},
#                                                               {'losses': 5,
#                                                                'ot': 3,
#                                                                'type': 'lastTen',
#                                                                'wins': 2}]},
#                                'regulationWins': 22,
#                                'row': 28,
#                                'streak': {'streakCode': 'OT1',
#                                           'streakNumber': 1,
#                                           'streakType': 'ot'},
#                                'team': {'id': 29,
#                                         'link': '/api/v1/teams/29',
#                                         'name': 'Columbus Blue Jackets'},
#                                'wildCardRank': '4'},
#                               {'conferenceHomeRank': '13',
#                                'conferenceL10Rank': '13',
#                                'conferenceRank': '14',
#                                'conferenceRoadRank': '14',
#                                'divisionHomeRank': '8',
#                                'divisionL10Rank': '6',
#                                'divisionRank': '7',
#                                'divisionRoadRank': '7',
#                                'gamesPlayed': 69,
#                                'goalsAgainst': 246,
#                                'goalsScored': 179,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '26',
#                                'leagueL10Rank': '25',
#                                'leagueRank': '28',
#                                'leagueRecord': {'losses': 36,
#                                                 'ot': 11,
#                                                 'type': 'league',
#                                                 'wins': 22},
#                                'leagueRoadRank': '30',
#                                'points': 55,
#                                'pointsPercentage': 0.39855072463768115,
#                                'ppConferenceRank': '14',
#                                'ppDivisionRank': '7',
#                                'ppLeagueRank': '28',
#                                'records': {'conferenceRecords': [{'losses': 24,
#                                                                   'ot': 8,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 8},
#                                                                  {'losses': 12,
#                                                                   'ot': 3,
#                                                                   'type': 'Western',
#                                                                   'wins': 14}],
#                                            'divisionRecords': [{'losses': 8,
#                                                                 'ot': 0,
#                                                                 'type': 'Central',
#                                                                 'wins': 6},
#                                                                {'losses': 13,
#                                                                 'ot': 4,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 2},
#                                                                {'losses': 4,
#                                                                 'ot': 3,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 8},
#                                                                {'losses': 11,
#                                                                 'ot': 4,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 6}],
#                                            'overallRecords': [{'losses': 16,
#                                                                'ot': 6,
#                                                                'type': 'home',
#                                                                'wins': 13},
#                                                               {'losses': 20,
#                                                                'ot': 5,
#                                                                'type': 'away',
#                                                                'wins': 9},
#                                                               {'losses': 4,
#                                                                'type': 'shootOuts',
#                                                                'wins': 1},
#                                                               {'losses': 6,
#                                                                'ot': 0,
#                                                                'type': 'lastTen',
#                                                                'wins': 4}]},
#                                'regulationWins': 17,
#                                'row': 21,
#                                'streak': {'streakCode': 'W1',
#                                           'streakNumber': 1,
#                                           'streakType': 'wins'},
#                                'team': {'id': 4,
#                                         'link': '/api/v1/teams/4',
#                                         'name': 'Philadelphia Flyers'},
#                                'wildCardRank': '8'},
#                               {'conferenceHomeRank': '12',
#                                'conferenceL10Rank': '16',
#                                'conferenceRank': '15',
#                                'conferenceRoadRank': '16',
#                                'divisionHomeRank': '7',
#                                'divisionL10Rank': '8',
#                                'divisionRank': '8',
#                                'divisionRoadRank': '8',
#                                'gamesPlayed': 69,
#                                'goalsAgainst': 258,
#                                'goalsScored': 213,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '24',
#                                'leagueL10Rank': '31',
#                                'leagueRank': '29',
#                                'leagueRecord': {'losses': 39,
#                                                 'ot': 6,
#                                                 'type': 'league',
#                                                 'wins': 24},
#                                'leagueRoadRank': '32',
#                                'points': 54,
#                                'pointsPercentage': 0.391304347826087,
#                                'ppConferenceRank': '15',
#                                'ppDivisionRank': '8',
#                                'ppLeagueRank': '29',
#                                'records': {'conferenceRecords': [{'losses': 23,
#                                                                   'ot': 4,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 15},
#                                                                  {'losses': 16,
#                                                                   'ot': 2,
#                                                                   'type': 'Western',
#                                                                   'wins': 9}],
#                                            'divisionRecords': [{'losses': 8,
#                                                                 'ot': 1,
#                                                                 'type': 'Central',
#                                                                 'wins': 4},
#                                                                {'losses': 11,
#                                                                 'ot': 2,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 6},
#                                                                {'losses': 8,
#                                                                 'ot': 1,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 5},
#                                                                {'losses': 12,
#                                                                 'ot': 2,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 9}],
#                                            'overallRecords': [{'losses': 15,
#                                                                'ot': 4,
#                                                                'type': 'home',
#                                                                'wins': 16},
#                                                               {'losses': 24,
#                                                                'ot': 2,
#                                                                'type': 'away',
#                                                                'wins': 8},
#                                                               {'losses': 4,
#                                                                'type': 'shootOuts',
#                                                                'wins': 3},
#                                                               {'losses': 7,
#                                                                'ot': 1,
#                                                                'type': 'lastTen',
#                                                                'wins': 2}]},
#                                'regulationWins': 16,
#                                'row': 21,
#                                'streak': {'streakCode': 'L1',
#                                           'streakNumber': 1,
#                                           'streakType': 'losses'},
#                                'team': {'id': 1,
#                                         'link': '/api/v1/teams/1',
#                                         'name': 'New Jersey Devils'},
#                                'wildCardRank': '9'}]},
#              {'conference': {'id': 6,
#                              'link': '/api/v1/conferences/6',
#                              'name': 'Eastern'},
#               'division': {'abbreviation': 'A',
#                            'id': 17,
#                            'link': '/api/v1/divisions/17',
#                            'name': 'Atlantic',
#                            'nameShort': 'ATL'},
#               'league': {'id': 133,
#                          'link': '/api/v1/league/133',
#                          'name': 'National Hockey League'},
#               'standingsType': 'regularSeason',
#               'teamRecords': [{'clinchIndicator': 'x',
#                                'conferenceHomeRank': '1',
#                                'conferenceL10Rank': '3',
#                                'conferenceRank': '1',
#                                'conferenceRoadRank': '4',
#                                'divisionHomeRank': '1',
#                                'divisionL10Rank': '3',
#                                'divisionRank': '1',
#                                'divisionRoadRank': '2',
#                                'gamesPlayed': 69,
#                                'goalsAgainst': 204,
#                                'goalsScored': 287,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '2',
#                                'leagueL10Rank': '5',
#                                'leagueRank': '2',
#                                'leagueRecord': {'losses': 15,
#                                                 'ot': 6,
#                                                 'type': 'league',
#                                                 'wins': 48},
#                                'leagueRoadRank': '5',
#                                'points': 102,
#                                'pointsPercentage': 0.7391304347826086,
#                                'ppConferenceRank': '1',
#                                'ppDivisionRank': '1',
#                                'ppLeagueRank': '2',
#                                'records': {'conferenceRecords': [{'losses': 7,
#                                                                   'ot': 3,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 30},
#                                                                  {'losses': 8,
#                                                                   'ot': 3,
#                                                                   'type': 'Western',
#                                                                   'wins': 18}],
#                                            'divisionRecords': [{'losses': 2,
#                                                                 'ot': 2,
#                                                                 'type': 'Central',
#                                                                 'wins': 10},
#                                                                {'losses': 2,
#                                                                 'ot': 2,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 13},
#                                                                {'losses': 6,
#                                                                 'ot': 1,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 8},
#                                                                {'losses': 5,
#                                                                 'ot': 1,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 17}],
#                                            'overallRecords': [{'losses': 6,
#                                                                'ot': 0,
#                                                                'type': 'home',
#                                                                'wins': 28},
#                                                               {'losses': 9,
#                                                                'ot': 6,
#                                                                'type': 'away',
#                                                                'wins': 20},
#                                                               {'losses': 4,
#                                                                'type': 'shootOuts',
#                                                                'wins': 3},
#                                                               {'losses': 2,
#                                                                'ot': 0,
#                                                                'type': 'lastTen',
#                                                                'wins': 8}]},
#                                'regulationWins': 36,
#                                'row': 45,
#                                'streak': {'streakCode': 'W4',
#                                           'streakNumber': 4,
#                                           'streakType': 'wins'},
#                                'team': {'id': 13,
#                                         'link': '/api/v1/teams/13',
#                                         'name': 'Florida Panthers'},
#                                'wildCardRank': '0'},
#                               {'conferenceHomeRank': '3',
#                                'conferenceL10Rank': '1',
#                                'conferenceRank': '3',
#                                'conferenceRoadRank': '8',
#                                'divisionHomeRank': '2',
#                                'divisionL10Rank': '1',
#                                'divisionRank': '2',
#                                'divisionRoadRank': '4',
#                                'gamesPlayed': 69,
#                                'goalsAgainst': 209,
#                                'goalsScored': 264,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '4',
#                                'leagueL10Rank': '3',
#                                'leagueRank': '4',
#                                'leagueRecord': {'losses': 19,
#                                                 'ot': 5,
#                                                 'type': 'league',
#                                                 'wins': 45},
#                                'leagueRoadRank': '10',
#                                'points': 95,
#                                'pointsPercentage': 0.6884057971014492,
#                                'ppConferenceRank': '3',
#                                'ppDivisionRank': '2',
#                                'ppLeagueRank': '4',
#                                'records': {'conferenceRecords': [{'losses': 10,
#                                                                   'ot': 2,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 26},
#                                                                  {'losses': 9,
# ...
#                                                               {'losses': 3,
#                                                                'type': 'shootOuts',
#                                                                'wins': 3},
#                                                               {'losses': 4,
#                                                                'ot': 3,
#                                                                'type': 'lastTen',
#                                                                'wins': 3}]},
#                                'regulationWins': 26,
#                                'row': 29,
#                                'streak': {'streakCode': 'OT1',
#                                           'streakNumber': 1,
#                                           'streakType': 'ot'},
#                                'team': {'id': 23,
#                                         'link': '/api/v1/teams/23',
#                                         'name': 'Vancouver Canucks'},
#                                'wildCardRank': '5'},
#                               {'conferenceHomeRank': '11',
#                                'conferenceL10Rank': '16',
#                                'conferenceRank': '12',
#                                'conferenceRoadRank': '12',
#                                'divisionHomeRank': '5',
#                                'divisionL10Rank': '8',
#                                'divisionRank': '6',
#                                'divisionRoadRank': '6',
#                                'gamesPlayed': 71,
#                                'goalsAgainst': 230,
#                                'goalsScored': 199,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '22',
#                                'leagueL10Rank': '32',
#                                'leagueRank': '22',
#                                'leagueRecord': {'losses': 31,
#                                                 'ot': 12,
#                                                 'type': 'league',
#                                                 'wins': 28},
#                                'leagueRoadRank': '21',
#                                'points': 68,
#                                'pointsPercentage': 0.4788732394366197,
#                                'ppConferenceRank': '13',
#                                'ppDivisionRank': '7',
#                                'ppLeagueRank': '23',
#                                'records': {'conferenceRecords': [{'losses': 8,
#                                                                   'ot': 6,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 13},
#                                                                  {'losses': 23,
#                                                                   'ot': 6,
#                                                                   'type': 'Western',
#                                                                   'wins': 15}],
#                                            'divisionRecords': [{'losses': 14,
#                                                                 'ot': 3,
#                                                                 'type': 'Central',
#                                                                 'wins': 5},
#                                                                {'losses': 2,
#                                                                 'ot': 3,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 9},
#                                                                {'losses': 9,
#                                                                 'ot': 3,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 10},
#                                                                {'losses': 6,
#                                                                 'ot': 3,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 4}],
#                                            'overallRecords': [{'losses': 16,
#                                                                'ot': 5,
#                                                                'type': 'home',
#                                                                'wins': 16},
#                                                               {'losses': 15,
#                                                                'ot': 7,
#                                                                'type': 'away',
#                                                                'wins': 12},
#                                                               {'losses': 5,
#                                                                'type': 'shootOuts',
#                                                                'wins': 4},
#                                                               {'losses': 7,
#                                                                'ot': 2,
#                                                                'type': 'lastTen',
#                                                                'wins': 1}]},
#                                'regulationWins': 19,
#                                'row': 24,
#                                'streak': {'streakCode': 'L1',
#                                           'streakNumber': 1,
#                                           'streakType': 'losses'},
#                                'team': {'id': 24,
#                                         'link': '/api/v1/teams/24',
#                                         'name': 'Anaheim Ducks'},
#                                'wildCardRank': '6'},
#                               {'conferenceHomeRank': '12',
#                                'conferenceL10Rank': '13',
#                                'conferenceRank': '13',
#                                'conferenceRoadRank': '14',
#                                'divisionHomeRank': '6',
#                                'divisionL10Rank': '7',
#                                'divisionRank': '7',
#                                'divisionRoadRank': '7',
#                                'gamesPlayed': 68,
#                                'goalsAgainst': 218,
#                                'goalsScored': 181,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '23',
#                                'leagueL10Rank': '26',
#                                'leagueRank': '23',
#                                'leagueRecord': {'losses': 31,
#                                                 'ot': 8,
#                                                 'type': 'league',
#                                                 'wins': 29},
#                                'leagueRoadRank': '23',
#                                'points': 66,
#                                'pointsPercentage': 0.4852941176470588,
#                                'ppConferenceRank': '12',
#                                'ppDivisionRank': '6',
#                                'ppLeagueRank': '22',
#                                'records': {'conferenceRecords': [{'losses': 12,
#                                                                   'ot': 5,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 14},
#                                                                  {'losses': 19,
#                                                                   'ot': 3,
#                                                                   'type': 'Western',
#                                                                   'wins': 15}],
#                                            'divisionRecords': [{'losses': 11,
#                                                                 'ot': 0,
#                                                                 'type': 'Central',
#                                                                 'wins': 7},
#                                                                {'losses': 6,
#                                                                 'ot': 3,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 7},
#                                                                {'losses': 8,
#                                                                 'ot': 3,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 8},
#                                                                {'losses': 6,
#                                                                 'ot': 2,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 7}],
#                                            'overallRecords': [{'losses': 15,
#                                                                'ot': 4,
#                                                                'type': 'home',
#                                                                'wins': 16},
#                                                               {'losses': 16,
#                                                                'ot': 4,
#                                                                'type': 'away',
#                                                                'wins': 13},
#                                                               {'losses': 2,
#                                                                'type': 'shootOuts',
#                                                                'wins': 2},
#                                                               {'losses': 6,
#                                                                'ot': 1,
#                                                                'type': 'lastTen',
#                                                                'wins': 3}]},
#                                'regulationWins': 20,
#                                'row': 27,
#                                'streak': {'streakCode': 'L3',
#                                           'streakNumber': 3,
#                                           'streakType': 'losses'},
#                                'team': {'id': 28,
#                                         'link': '/api/v1/teams/28',
#                                         'name': 'San Jose Sharks'},
#                                'wildCardRank': '7'},
#                               {'conferenceHomeRank': '15',
#                                'conferenceL10Rank': '11',
#                                'conferenceRank': '15',
#                                'conferenceRoadRank': '16',
#                                'divisionHomeRank': '8',
#                                'divisionL10Rank': '5',
#                                'divisionRank': '8',
#                                'divisionRoadRank': '8',
#                                'gamesPlayed': 69,
#                                'goalsAgainst': 242,
#                                'goalsScored': 182,
#                                'lastUpdated': '2022-04-05T15:50:36Z',
#                                'leagueHomeRank': '30',
#                                'leagueL10Rank': '18',
#                                'leagueRank': '30',
#                                'leagueRecord': {'losses': 41,
#                                                 'ot': 6,
#                                                 'type': 'league',
#                                                 'wins': 22},
#                                'leagueRoadRank': '29',
#                                'points': 50,
#                                'pointsPercentage': 0.36231884057971014,
#                                'ppConferenceRank': '15',
#                                'ppDivisionRank': '8',
#                                'ppLeagueRank': '30',
#                                'records': {'conferenceRecords': [{'losses': 13,
#                                                                   'ot': 6,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 11},
#                                                                  {'losses': 28,
#                                                                   'ot': 0,
#                                                                   'type': 'Western',
#                                                                   'wins': 11}],
#                                            'divisionRecords': [{'losses': 12,
#                                                                 'ot': 0,
#                                                                 'type': 'Central',
#                                                                 'wins': 6},
#                                                                {'losses': 5,
#                                                                 'ot': 3,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 7},
#                                                                {'losses': 16,
#                                                                 'ot': 0,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 5},
#                                                                {'losses': 8,
#                                                                 'ot': 3,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 4}],
#                                            'overallRecords': [{'losses': 20,
#                                                                'ot': 3,
#                                                                'type': 'home',
#                                                                'wins': 12},
#                                                               {'losses': 21,
#                                                                'ot': 3,
#                                                                'type': 'away',
#                                                                'wins': 10},
#                                                               {'losses': 1,
#                                                                'type': 'shootOuts',
#                                                                'wins': 2},
#                                                               {'losses': 4,
#                                                                'ot': 1,
#                                                                'type': 'lastTen',
#                                                                'wins': 5}]},
#                                'regulationWins': 19,
#                                'row': 20,
#                                'streak': {'streakCode': 'W1',
#                                           'streakNumber': 1,
#                                           'streakType': 'wins'},
#                                'team': {'id': 55,
#                                         'link': '/api/v1/teams/55',
#                                         'name': 'Seattle Kraken'},
#                                'wildCardRank': '9'}]}]}

# %%
#finding variables in hockey_json
#name of team
team_name = hockey_json['records'][0]['teamRecords'][0]['team']['name']

#name of Division
team_division = hockey_json['records'][0]['division']['name']

#name of Conference
team_conference = hockey_json['records'][0]['conference']['name']

#name of league
team_league = hockey_json['records'][0]['league']['name']

#number of games played "gp"
team_gp = hockey_json['records'][0]['teamRecords'][0]['gamesPlayed']

#number of wins "W"
team_W = hockey_json['records'][0]['teamRecords'][0]['leagueRecord']['wins']

#number of losses "L"
team_L = hockey_json['records'][0]['teamRecords'][0]['leagueRecord']['losses']

#number of overtime losses "QTL"
team_QTL = hockey_json['records'][0]['teamRecords'][0]['leagueRecord']['ot']

#number of points overall "Pts"
team_Pts = hockey_json['records'][0]['teamRecords'][0]['points']

#number of total goals scored by the team "GF"
team_GF = hockey_json['records'][0]['teamRecords'][0]['goalsScored']

#number of total goals allowed by the team "GA"
team_GA = hockey_json['records'][0]['teamRecords'][0]['goalsAgainst']

#goal differential "diff"
team_diff = team_GF - team_GA

#win loss in last ten games "L10"
team_L10_w = hockey_json['records'][0]['teamRecords'][0]['records']['overallRecords'][3]['wins']
team_L10_l = hockey_json['records'][0]['teamRecords'][0]['records']['overallRecords'][3]['losses']
team_L10_o = hockey_json['records'][0]['teamRecords'][0]['records']['overallRecords'][3]['ot']
team_L10 = f"{team_L10_w}-{team_L10_l}-{team_L10_o}"

#game streak "strk"
team_strk = hockey_json['records'][0]['teamRecords'][0]['streak']['streakCode']


#empty dataframe
test_df = pd.DataFrame(columns=('Team','Conference','Division','League','GP','W','L','QTL','Pts','GF','GA','Diff','L10','Strk'))

test = {'Team' : team_name,
           'Division':team_division,
           'Conference':team_conference,
           'League':team_league,
           'GP': team_gp,
           'W': team_W,
           'L': team_L,
           'QTL': team_QTL,
           'Pts': team_Pts,
           'GF': team_GF,
           'GA': team_GA,
           'Diff': team_diff,
           'L10': team_L10,
           'Strk': team_strk}

test_df = test_df.append(test,ignore_index=True)

test_df.head()
# Out:
#                   Team Conference      Division                  League  GP  \
# 0  Carolina Hurricanes    Eastern  Metropolitan  National Hockey League  69
#
#     W   L QTL Pts   GF   GA Diff    L10 Strk
# 0  45  16   8  98  230  164   66  4-3-3   L1
