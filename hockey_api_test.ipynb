# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import requests
from pprint import pprint
# Permanently changes the pandas settings
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\kirkj\AppData\Local\Temp/ipykernel_22312/3144044782.py:12: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
#basic call for standings for a given season
# "https://statsapi.web.nhl.com/api/v1/standings"
#indicates what season we want. format year start year end
season=""
# exanded variable required for win loss tally
# &expand=standings.record

query_url= f"https://statsapi.web.nhl.com/api/v1/standings?expand=standings.record{season}"
query_url
# Out:
# 'https://statsapi.web.nhl.com/api/v1/standings?expand=standings.record'

# %%
#request data from API
hockey_response = requests.get(query_url)
hockey_response
# Out:
# <Response [200]>

# %%
hockey_json = hockey_response.json()
pprint(hockey_json)
# Out:
# {'copyright': 'NHL and the NHL Shield are registered trademarks of the '
#               'National Hockey League. NHL and NHL team marks are the property '
#               'of the NHL and its teams. © NHL 2022. All Rights Reserved.',
#  'records': [{'conference': {'id': 6,
#                              'link': '/api/v1/conferences/6',
#                              'name': 'Eastern'},
#               'division': {'abbreviation': 'M',
#                            'id': 18,
#                            'link': '/api/v1/divisions/18',
#                            'name': 'Metropolitan',
#                            'nameShort': 'Metro'},
#               'league': {'id': 133,
#                          'link': '/api/v1/league/133',
#                          'name': 'National Hockey League'},
#               'standingsType': 'regularSeason',
#               'teamRecords': [{'conferenceHomeRank': '2',
#                                'conferenceL10Rank': '9',
#                                'conferenceRank': '2',
#                                'conferenceRoadRank': '7',
#                                'divisionHomeRank': '1',
#                                'divisionL10Rank': '4',
#                                'divisionRank': '1',
#                                'divisionRoadRank': '4',
#                                'gamesPlayed': 70,
#                                'goalsAgainst': 168,
#                                'goalsScored': 232,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '3',
#                                'leagueL10Rank': '20',
#                                'leagueRank': '3',
#                                'leagueRecord': {'losses': 17,
#                                                 'ot': 8,
#                                                 'type': 'league',
#                                                 'wins': 45},
#                                'leagueRoadRank': '9',
#                                'points': 98,
#                                'pointsPercentage': 0.7,
#                                'ppConferenceRank': '2',
#                                'ppDivisionRank': '1',
#                                'ppLeagueRank': '3',
#                                'records': {'conferenceRecords': [{'losses': 12,
#                                                                   'ot': 6,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 24},
#                                                                  {'losses': 5,
#                                                                   'ot': 2,
#                                                                   'type': 'Western',
#                                                                   'wins': 21}],
#                                            'divisionRecords': [{'losses': 3,
#                                                                 'ot': 1,
#                                                                 'type': 'Central',
#                                                                 'wins': 9},
#                                                                {'losses': 5,
#                                                                 'ot': 5,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 12},
#                                                                {'losses': 2,
#                                                                 'ot': 1,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 12},
#                                                                {'losses': 7,
#                                                                 'ot': 1,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 12}],
#                                            'overallRecords': [{'losses': 6,
#                                                                'ot': 4,
#                                                                'type': 'home',
#                                                                'wins': 25},
#                                                               {'losses': 11,
#                                                                'ot': 4,
#                                                                'type': 'away',
#                                                                'wins': 20},
#                                                               {'losses': 2,
#                                                                'type': 'shootOuts',
#                                                                'wins': 1},
#                                                               {'losses': 3,
#                                                                'ot': 3,
#                                                                'type': 'lastTen',
#                                                                'wins': 4}]},
#                                'regulationWins': 39,
#                                'row': 44,
#                                'streak': {'streakCode': 'L2',
#                                           'streakNumber': 2,
#                                           'streakType': 'losses'},
#                                'team': {'id': 12,
#                                         'link': '/api/v1/teams/12',
#                                         'name': 'Carolina Hurricanes'},
#                                'wildCardRank': '0'},
#                               {'conferenceHomeRank': '4',
#                                'conferenceL10Rank': '3',
#                                'conferenceRank': '4',
#                                'conferenceRoadRank': '2',
#                                'divisionHomeRank': '2',
#                                'divisionL10Rank': '1',
#                                'divisionRank': '2',
#                                'divisionRoadRank': '2',
#                                'gamesPlayed': 71,
#                                'goalsAgainst': 186,
#                                'goalsScored': 217,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '7',
#                                'leagueL10Rank': '5',
#                                'leagueRank': '5',
#                                'leagueRecord': {'losses': 20,
#                                                 'ot': 6,
#                                                 'type': 'league',
#                                                 'wins': 45},
#                                'leagueRoadRank': '2',
#                                'points': 96,
#                                'pointsPercentage': 0.676056338028169,
#                                'ppConferenceRank': '4',
#                                'ppDivisionRank': '2',
#                                'ppLeagueRank': '5',
#                                'records': {'conferenceRecords': [{'losses': 9,
#                                                                   'ot': 2,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 29},
#                                                                  {'losses': 11,
#                                                                   'ot': 4,
#                                                                   'type': 'Western',
#                                                                   'wins': 16}],
#                                            'divisionRecords': [{'losses': 6,
#                                                                 'ot': 1,
#                                                                 'type': 'Central',
#                                                                 'wins': 8},
#                                                                {'losses': 2,
#                                                                 'ot': 1,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 17},
#                                                                {'losses': 5,
#                                                                 'ot': 3,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 8},
#                                                                {'losses': 7,
#                                                                 'ot': 1,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 12}],
#                                            'overallRecords': [{'losses': 7,
#                                                                'ot': 4,
#                                                                'type': 'home',
#                                                                'wins': 22},
#                                                               {'losses': 13,
#                                                                'ot': 2,
#                                                                'type': 'away',
#                                                                'wins': 23},
#                                                               {'losses': 3,
#                                                                'type': 'shootOuts',
#                                                                'wins': 4},
#                                                               {'losses': 2,
#                                                                'ot': 1,
#                                                                'type': 'lastTen',
#                                                                'wins': 7}]},
#                                'regulationWins': 37,
#                                'row': 41,
#                                'streak': {'streakCode': 'W1',
#                                           'streakNumber': 1,
#                                           'streakType': 'wins'},
#                                'team': {'id': 3,
#                                         'link': '/api/v1/teams/3',
#                                         'name': 'New York Rangers'},
#                                'wildCardRank': '0'},
#                               {'conferenceHomeRank': '7',
#                                'conferenceL10Rank': '11',
#                                'conferenceRank': '7',
#                                'conferenceRoadRank': '1',
#                                'divisionHomeRank': '3',
#                                'divisionL10Rank': '5',
#                                'divisionRank': '3',
#                                'divisionRoadRank': '1',
#                                'gamesPlayed': 71,
#                                'goalsAgainst': 194,
#                                'goalsScored': 237,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '14',
#                                'leagueL10Rank': '22',
#                                'leagueRank': '8',
#                                'leagueRecord': {'losses': 20,
#                                                 'ot': 10,
#                                                 'type': 'league',
#                                                 'wins': 41},
#                                'leagueRoadRank': '1',
#                                'points': 92,
#                                'pointsPercentage': 0.647887323943662,
#                                'ppConferenceRank': '7',
#                                'ppDivisionRank': '3',
#                                'ppLeagueRank': '10',
#                                'records': {'conferenceRecords': [{'losses': 12,
#                                                                   'ot': 5,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 24},
#                                                                  {'losses': 8,
#                                                                   'ot': 5,
#                                                                   'type': 'Western',
#                                                                   'wins': 17}],
#                                            'divisionRecords': [{'losses': 4,
#                                                                 'ot': 3,
#                                                                 'type': 'Central',
#                                                                 'wins': 8},
#                                                                {'losses': 6,
#                                                                 'ot': 3,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 12},
#                                                                {'losses': 4,
#                                                                 'ot': 2,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 9},
#                                                                {'losses': 6,
#                                                                 'ot': 2,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 12}],
#                                            'overallRecords': [{'losses': 11,
#                                                                'ot': 5,
#                                                                'type': 'home',
#                                                                'wins': 19},
#                                                               {'losses': 9,
#                                                                'ot': 5,
#                                                                'type': 'away',
#                                                                'wins': 22},
#                                                               {'losses': 6,
#                                                                'type': 'shootOuts',
#                                                                'wins': 3},
#                                                               {'losses': 4,
#                                                                'ot': 1,
#                                                                'type': 'lastTen',
#                                                                'wins': 5}]},
#                                'regulationWins': 33,
#                                'row': 38,
#                                'streak': {'streakCode': 'L2',
#                                           'streakNumber': 2,
#                                           'streakType': 'losses'},
#                                'team': {'id': 5,
#                                         'link': '/api/v1/teams/5',
#                                         'name': 'Pittsburgh Penguins'},
#                                'wildCardRank': '0'},
#                               {'conferenceHomeRank': '11',
#                                'conferenceL10Rank': '7',
#                                'conferenceRank': '8',
#                                'conferenceRoadRank': '3',
#                                'divisionHomeRank': '6',
#                                'divisionL10Rank': '3',
#                                'divisionRank': '4',
#                                'divisionRoadRank': '3',
#                                'gamesPlayed': 69,
#                                'goalsAgainst': 202,
#                                'goalsScored': 226,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '21',
#                                'leagueL10Rank': '17',
#                                'leagueRank': '15',
#                                'leagueRecord': {'losses': 22,
#                                                 'ot': 10,
#                                                 'type': 'league',
#                                                 'wins': 37},
#                                'leagueRoadRank': '3',
#                                'points': 84,
#                                'pointsPercentage': 0.6086956521739131,
#                                'ppConferenceRank': '8',
#                                'ppDivisionRank': '4',
#                                'ppLeagueRank': '14',
#                                'records': {'conferenceRecords': [{'losses': 12,
#                                                                   'ot': 4,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 24},
#                                                                  {'losses': 10,
#                                                                   'ot': 6,
#                                                                   'type': 'Western',
#                                                                   'wins': 13}],
#                                            'divisionRecords': [{'losses': 4,
#                                                                 'ot': 3,
#                                                                 'type': 'Central',
#                                                                 'wins': 7},
#                                                                {'losses': 6,
#                                                                 'ot': 3,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 10},
#                                                                {'losses': 6,
#                                                                 'ot': 3,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 6},
#                                                                {'losses': 6,
#                                                                 'ot': 1,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 14}],
#                                            'overallRecords': [{'losses': 15,
#                                                                'ot': 5,
#                                                                'type': 'home',
#                                                                'wins': 16},
#                                                               {'losses': 7,
#                                                                'ot': 5,
#                                                                'type': 'away',
#                                                                'wins': 21},
#                                                               {'losses': 2,
#                                                                'type': 'shootOuts',
#                                                                'wins': 5},
#                                                               {'losses': 4,
#                                                                'ot': 0,
#                                                                'type': 'lastTen',
#                                                                'wins': 6}]},
#                                'regulationWins': 28,
#                                'row': 32,
#                                'streak': {'streakCode': 'L2',
#                                           'streakNumber': 2,
#                                           'streakType': 'losses'},
#                                'team': {'id': 15,
#                                         'link': '/api/v1/teams/15',
#                                         'name': 'Washington Capitals'},
#                                'wildCardRank': '2'},
#                               {'conferenceHomeRank': '9',
#                                'conferenceL10Rank': '6',
#                                'conferenceRank': '9',
#                                'conferenceRoadRank': '9',
#                                'divisionHomeRank': '4',
#                                'divisionL10Rank': '2',
#                                'divisionRank': '5',
#                                'divisionRoadRank': '5',
#                                'gamesPlayed': 69,
#                                'goalsAgainst': 189,
#                                'goalsScored': 192,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '17',
#                                'leagueL10Rank': '11',
#                                'leagueRank': '20',
#                                'leagueRecord': {'losses': 28,
#                                                 'ot': 9,
#                                                 'type': 'league',
#                                                 'wins': 32},
#                                'leagueRoadRank': '20',
#                                'points': 73,
#                                'pointsPercentage': 0.5289855072463768,
#                                'ppConferenceRank': '9',
#                                'ppDivisionRank': '5',
#                                'ppLeagueRank': '19',
#                                'records': {'conferenceRecords': [{'losses': 15,
#                                                                   'ot': 4,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 19},
#                                                                  {'losses': 13,
#                                                                   'ot': 5,
#                                                                   'type': 'Western',
#                                                                   'wins': 13}],
#                                            'divisionRecords': [{'losses': 6,
#                                                                 'ot': 2,
#                                                                 'type': 'Central',
#                                                                 'wins': 7},
#                                                                {'losses': 9,
#                                                                 'ot': 2,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 8},
#                                                                {'losses': 7,
#                                                                 'ot': 3,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 6},
#                                                                {'losses': 6,
#                                                                 'ot': 2,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 11}],
#                                            'overallRecords': [{'losses': 13,
#                                                                'ot': 4,
#                                                                'type': 'home',
#                                                                'wins': 18},
#                                                               {'losses': 15,
#                                                                'ot': 5,
#                                                                'type': 'away',
#                                                                'wins': 14},
#                                                               {'losses': 6,
#                                                                'type': 'shootOuts',
#                                                                'wins': 1},
#                                                               {'losses': 4,
#                                                                'ot': 0,
#                                                                'type': 'lastTen',
#                                                                'wins': 6}]},
#                                'regulationWins': 30,
#                                'row': 31,
#                                'streak': {'streakCode': 'L1',
#                                           'streakNumber': 1,
#                                           'streakType': 'losses'},
#                                'team': {'id': 2,
#                                         'link': '/api/v1/teams/2',
#                                         'name': 'New York Islanders'},
#                                'wildCardRank': '3'},
#                               {'conferenceHomeRank': '10',
#                                'conferenceL10Rank': '14',
#                                'conferenceRank': '10',
#                                'conferenceRoadRank': '10',
#                                'divisionHomeRank': '5',
#                                'divisionL10Rank': '6',
#                                'divisionRank': '6',
#                                'divisionRoadRank': '6',
#                                'gamesPlayed': 71,
#                                'goalsAgainst': 265,
#                                'goalsScored': 229,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '19',
#                                'leagueL10Rank': '27',
#                                'leagueRank': '21',
#                                'leagueRecord': {'losses': 32,
#                                                 'ot': 6,
#                                                 'type': 'league',
#                                                 'wins': 33},
#                                'leagueRoadRank': '21',
#                                'points': 72,
#                                'pointsPercentage': 0.5070422535211268,
#                                'ppConferenceRank': '10',
#                                'ppDivisionRank': '6',
#                                'ppLeagueRank': '21',
#                                'records': {'conferenceRecords': [{'losses': 23,
#                                                                   'ot': 2,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 18},
#                                                                  {'losses': 9,
#                                                                   'ot': 4,
#                                                                   'type': 'Western',
#                                                                   'wins': 15}],
#                                            'divisionRecords': [{'losses': 4,
#                                                                 'ot': 2,
#                                                                 'type': 'Central',
#                                                                 'wins': 10},
#                                                                {'losses': 8,
#                                                                 'ot': 2,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 9},
#                                                                {'losses': 5,
#                                                                 'ot': 2,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 5},
#                                                                {'losses': 15,
#                                                                 'ot': 0,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 9}],
#                                            'overallRecords': [{'losses': 14,
#                                                                'ot': 4,
#                                                                'type': 'home',
#                                                                'wins': 18},
#                                                               {'losses': 18,
#                                                                'ot': 2,
#                                                                'type': 'away',
#                                                                'wins': 15},
#                                                               {'losses': 2,
#                                                                'type': 'shootOuts',
#                                                                'wins': 4},
#                                                               {'losses': 5,
#                                                                'ot': 3,
#                                                                'type': 'lastTen',
#                                                                'wins': 2}]},
#                                'regulationWins': 23,
#                                'row': 29,
#                                'streak': {'streakCode': 'W1',
#                                           'streakNumber': 1,
#                                           'streakType': 'wins'},
#                                'team': {'id': 29,
#                                         'link': '/api/v1/teams/29',
#                                         'name': 'Columbus Blue Jackets'},
#                                'wildCardRank': '4'},
#                               {'conferenceHomeRank': '14',
#                                'conferenceL10Rank': '15',
#                                'conferenceRank': '14',
#                                'conferenceRoadRank': '14',
#                                'divisionHomeRank': '8',
#                                'divisionL10Rank': '7',
#                                'divisionRank': '7',
#                                'divisionRoadRank': '7',
#                                'gamesPlayed': 70,
#                                'goalsAgainst': 250,
#                                'goalsScored': 181,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '27',
#                                'leagueL10Rank': '29',
#                                'leagueRank': '28',
#                                'leagueRecord': {'losses': 37,
#                                                 'ot': 11,
#                                                 'type': 'league',
#                                                 'wins': 22},
#                                'leagueRoadRank': '30',
#                                'points': 55,
#                                'pointsPercentage': 0.39285714285714285,
#                                'ppConferenceRank': '14',
#                                'ppDivisionRank': '7',
#                                'ppLeagueRank': '28',
#                                'records': {'conferenceRecords': [{'losses': 25,
#                                                                   'ot': 8,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 8},
#                                                                  {'losses': 12,
#                                                                   'ot': 3,
#                                                                   'type': 'Western',
#                                                                   'wins': 14}],
#                                            'divisionRecords': [{'losses': 8,
#                                                                 'ot': 0,
#                                                                 'type': 'Central',
#                                                                 'wins': 6},
#                                                                {'losses': 13,
#                                                                 'ot': 4,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 2},
#                                                                {'losses': 4,
#                                                                 'ot': 3,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 8},
#                                                                {'losses': 12,
#                                                                 'ot': 4,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 6}],
#                                            'overallRecords': [{'losses': 17,
#                                                                'ot': 6,
#                                                                'type': 'home',
#                                                                'wins': 13},
#                                                               {'losses': 20,
#                                                                'ot': 5,
#                                                                'type': 'away',
#                                                                'wins': 9},
#                                                               {'losses': 4,
#                                                                'type': 'shootOuts',
#                                                                'wins': 1},
#                                                               {'losses': 7,
#                                                                'ot': 0,
#                                                                'type': 'lastTen',
#                                                                'wins': 3}]},
#                                'regulationWins': 17,
#                                'row': 21,
#                                'streak': {'streakCode': 'L1',
#                                           'streakNumber': 1,
#                                           'streakType': 'losses'},
#                                'team': {'id': 4,
#                                         'link': '/api/v1/teams/4',
#                                         'name': 'Philadelphia Flyers'},
#                                'wildCardRank': '8'},
#                               {'conferenceHomeRank': '12',
#                                'conferenceL10Rank': '16',
#                                'conferenceRank': '15',
#                                'conferenceRoadRank': '16',
#                                'divisionHomeRank': '7',
#                                'divisionL10Rank': '8',
#                                'divisionRank': '8',
#                                'divisionRoadRank': '8',
#                                'gamesPlayed': 70,
#                                'goalsAgainst': 261,
#                                'goalsScored': 214,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '24',
#                                'leagueL10Rank': '31',
#                                'leagueRank': '29',
#                                'leagueRecord': {'losses': 40,
#                                                 'ot': 6,
#                                                 'type': 'league',
#                                                 'wins': 24},
#                                'leagueRoadRank': '32',
#                                'points': 54,
#                                'pointsPercentage': 0.38571428571428573,
#                                'ppConferenceRank': '15',
#                                'ppDivisionRank': '8',
#                                'ppLeagueRank': '29',
#                                'records': {'conferenceRecords': [{'losses': 24,
#                                                                   'ot': 4,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 15},
#                                                                  {'losses': 16,
#                                                                   'ot': 2,
#                                                                   'type': 'Western',
#                                                                   'wins': 9}],
#                                            'divisionRecords': [{'losses': 8,
#                                                                 'ot': 1,
#                                                                 'type': 'Central',
#                                                                 'wins': 4},
#                                                                {'losses': 11,
#                                                                 'ot': 2,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 6},
#                                                                {'losses': 8,
#                                                                 'ot': 1,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 5},
#                                                                {'losses': 13,
#                                                                 'ot': 2,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 9}],
#                                            'overallRecords': [{'losses': 16,
#                                                                'ot': 4,
#                                                                'type': 'home',
#                                                                'wins': 16},
#                                                               {'losses': 24,
#                                                                'ot': 2,
#                                                                'type': 'away',
#                                                                'wins': 8},
#                                                               {'losses': 4,
#                                                                'type': 'shootOuts',
#                                                                'wins': 3},
#                                                               {'losses': 7,
#                                                                'ot': 1,
#                                                                'type': 'lastTen',
#                                                                'wins': 2}]},
#                                'regulationWins': 16,
#                                'row': 21,
#                                'streak': {'streakCode': 'L2',
#                                           'streakNumber': 2,
#                                           'streakType': 'losses'},
#                                'team': {'id': 1,
#                                         'link': '/api/v1/teams/1',
#                                         'name': 'New Jersey Devils'},
#                                'wildCardRank': '9'}]},
#              {'conference': {'id': 6,
#                              'link': '/api/v1/conferences/6',
#                              'name': 'Eastern'},
#               'division': {'abbreviation': 'A',
#                            'id': 17,
#                            'link': '/api/v1/divisions/17',
#                            'name': 'Atlantic',
#                            'nameShort': 'ATL'},
#               'league': {'id': 133,
#                          'link': '/api/v1/league/133',
#                          'name': 'National Hockey League'},
#               'standingsType': 'regularSeason',
#               'teamRecords': [{'clinchIndicator': 'x',
#                                'conferenceHomeRank': '1',
#                                'conferenceL10Rank': '1',
#                                'conferenceRank': '1',
#                                'conferenceRoadRank': '5',
#                                'divisionHomeRank': '1',
#                                'divisionL10Rank': '1',
#                                'divisionRank': '1',
#                                'divisionRoadRank': '2',
#                                'gamesPlayed': 70,
#                                'goalsAgainst': 210,
#                                'goalsScored': 294,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '2',
#                                'leagueL10Rank': '3',
#                                'leagueRank': '2',
#                                'leagueRecord': {'losses': 15,
#                                                 'ot': 6,
#                                                 'type': 'league',
#                                                 'wins': 49},
#                                'leagueRoadRank': '7',
#                                'points': 104,
#                                'pointsPercentage': 0.7428571428571429,
#                                'ppConferenceRank': '1',
#                                'ppDivisionRank': '1',
#                                'ppLeagueRank': '2',
#                                'records': {'conferenceRecords': [{'losses': 7,
#                                                                   'ot': 3,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 31},
#                                                                  {'losses': 8,
#                                                                   'ot': 3,
#                                                                   'type': 'Western',
#                                                                   'wins': 18}],
#                                            'divisionRecords': [{'losses': 2,
#                                                                 'ot': 2,
#                                                                 'type': 'Central',
#                                                                 'wins': 10},
#                                                                {'losses': 2,
#                                                                 'ot': 2,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 14},
#                                                                {'losses': 6,
#                                                                 'ot': 1,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 8},
#                                                                {'losses': 5,
#                                                                 'ot': 1,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 17}],
#                                            'overallRecords': [{'losses': 6,
#                                                                'ot': 0,
#                                                                'type': 'home',
#                                                                'wins': 29},
#                                                               {'losses': 9,
#                                                                'ot': 6,
#                                                                'type': 'away',
#                                                                'wins': 20},
#                                                               {'losses': 4,
#                                                                'type': 'shootOuts',
#                                                                'wins': 3},
#                                                               {'losses': 2,
#                                                                'ot': 0,
#                                                                'type': 'lastTen',
#                                                                'wins': 8}]},
#                                'regulationWins': 36,
#                                'row': 46,
#                                'streak': {'streakCode': 'W5',
#                                           'streakNumber': 5,
#                                           'streakType': 'wins'},
#                                'team': {'id': 13,
#                                         'link': '/api/v1/teams/13',
#                                         'name': 'Florida Panthers'},
#                                'wildCardRank': '0'},
#                               {'conferenceHomeRank': '3',
#                                'conferenceL10Rank': '2',
#                                'conferenceRank': '3',
#                                'conferenceRoadRank': '8',
#                                'divisionHomeRank': '2',
#                                'divisionL10Rank': '2',
#                                'divisionRank': '2',
#                                'divisionRoadRank': '4',
#                                'gamesPlayed': 70,
#                                'goalsAgainst': 216,
#                                'goalsScored': 270,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '4',
#                                'leagueL10Rank': '4',
#                                'leagueRank': '4',
#                                'leagueRecord': {'losses': 19,
#                                                 'ot': 6,
#                                                 'type': 'league',
#                                                 'wins': 45},
#                                'leagueRoadRank': '10',
#                                'points': 96,
#                                'pointsPercentage': 0.6857142857142857,
#                                'ppConferenceRank': '3',
#                                'ppDivisionRank': '2',
#                                'ppLeagueRank': '4',
#                                'records': {'conferenceRecords': [{'losses': 10,
#                                                                   'ot': 3,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 26},
#                                                                  {'losses': 9,
# ...
#                                                               {'losses': 3,
#                                                                'type': 'shootOuts',
#                                                                'wins': 3},
#                                                               {'losses': 4,
#                                                                'ot': 3,
#                                                                'type': 'lastTen',
#                                                                'wins': 3}]},
#                                'regulationWins': 26,
#                                'row': 29,
#                                'streak': {'streakCode': 'OT1',
#                                           'streakNumber': 1,
#                                           'streakType': 'ot'},
#                                'team': {'id': 23,
#                                         'link': '/api/v1/teams/23',
#                                         'name': 'Vancouver Canucks'},
#                                'wildCardRank': '5'},
#                               {'conferenceHomeRank': '12',
#                                'conferenceL10Rank': '16',
#                                'conferenceRank': '12',
#                                'conferenceRoadRank': '12',
#                                'divisionHomeRank': '6',
#                                'divisionL10Rank': '8',
#                                'divisionRank': '6',
#                                'divisionRoadRank': '6',
#                                'gamesPlayed': 71,
#                                'goalsAgainst': 230,
#                                'goalsScored': 199,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '23',
#                                'leagueL10Rank': '32',
#                                'leagueRank': '22',
#                                'leagueRecord': {'losses': 31,
#                                                 'ot': 12,
#                                                 'type': 'league',
#                                                 'wins': 28},
#                                'leagueRoadRank': '22',
#                                'points': 68,
#                                'pointsPercentage': 0.4788732394366197,
#                                'ppConferenceRank': '13',
#                                'ppDivisionRank': '7',
#                                'ppLeagueRank': '23',
#                                'records': {'conferenceRecords': [{'losses': 8,
#                                                                   'ot': 6,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 13},
#                                                                  {'losses': 23,
#                                                                   'ot': 6,
#                                                                   'type': 'Western',
#                                                                   'wins': 15}],
#                                            'divisionRecords': [{'losses': 14,
#                                                                 'ot': 3,
#                                                                 'type': 'Central',
#                                                                 'wins': 5},
#                                                                {'losses': 2,
#                                                                 'ot': 3,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 9},
#                                                                {'losses': 9,
#                                                                 'ot': 3,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 10},
#                                                                {'losses': 6,
#                                                                 'ot': 3,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 4}],
#                                            'overallRecords': [{'losses': 16,
#                                                                'ot': 5,
#                                                                'type': 'home',
#                                                                'wins': 16},
#                                                               {'losses': 15,
#                                                                'ot': 7,
#                                                                'type': 'away',
#                                                                'wins': 12},
#                                                               {'losses': 5,
#                                                                'type': 'shootOuts',
#                                                                'wins': 4},
#                                                               {'losses': 7,
#                                                                'ot': 2,
#                                                                'type': 'lastTen',
#                                                                'wins': 1}]},
#                                'regulationWins': 19,
#                                'row': 24,
#                                'streak': {'streakCode': 'L1',
#                                           'streakNumber': 1,
#                                           'streakType': 'losses'},
#                                'team': {'id': 24,
#                                         'link': '/api/v1/teams/24',
#                                         'name': 'Anaheim Ducks'},
#                                'wildCardRank': '6'},
#                               {'conferenceHomeRank': '11',
#                                'conferenceL10Rank': '13',
#                                'conferenceRank': '13',
#                                'conferenceRoadRank': '14',
#                                'divisionHomeRank': '5',
#                                'divisionL10Rank': '7',
#                                'divisionRank': '7',
#                                'divisionRoadRank': '7',
#                                'gamesPlayed': 69,
#                                'goalsAgainst': 220,
#                                'goalsScored': 182,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '22',
#                                'leagueL10Rank': '26',
#                                'leagueRank': '23',
#                                'leagueRecord': {'losses': 31,
#                                                 'ot': 9,
#                                                 'type': 'league',
#                                                 'wins': 29},
#                                'leagueRoadRank': '24',
#                                'points': 67,
#                                'pointsPercentage': 0.4855072463768116,
#                                'ppConferenceRank': '12',
#                                'ppDivisionRank': '6',
#                                'ppLeagueRank': '22',
#                                'records': {'conferenceRecords': [{'losses': 12,
#                                                                   'ot': 5,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 14},
#                                                                  {'losses': 19,
#                                                                   'ot': 4,
#                                                                   'type': 'Western',
#                                                                   'wins': 15}],
#                                            'divisionRecords': [{'losses': 11,
#                                                                 'ot': 0,
#                                                                 'type': 'Central',
#                                                                 'wins': 7},
#                                                                {'losses': 6,
#                                                                 'ot': 3,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 7},
#                                                                {'losses': 8,
#                                                                 'ot': 4,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 8},
#                                                                {'losses': 6,
#                                                                 'ot': 2,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 7}],
#                                            'overallRecords': [{'losses': 15,
#                                                                'ot': 5,
#                                                                'type': 'home',
#                                                                'wins': 16},
#                                                               {'losses': 16,
#                                                                'ot': 4,
#                                                                'type': 'away',
#                                                                'wins': 13},
#                                                               {'losses': 2,
#                                                                'type': 'shootOuts',
#                                                                'wins': 2},
#                                                               {'losses': 6,
#                                                                'ot': 1,
#                                                                'type': 'lastTen',
#                                                                'wins': 3}]},
#                                'regulationWins': 20,
#                                'row': 27,
#                                'streak': {'streakCode': 'OT1',
#                                           'streakNumber': 1,
#                                           'streakType': 'ot'},
#                                'team': {'id': 28,
#                                         'link': '/api/v1/teams/28',
#                                         'name': 'San Jose Sharks'},
#                                'wildCardRank': '7'},
#                               {'conferenceHomeRank': '15',
#                                'conferenceL10Rank': '11',
#                                'conferenceRank': '15',
#                                'conferenceRoadRank': '16',
#                                'divisionHomeRank': '8',
#                                'divisionL10Rank': '5',
#                                'divisionRank': '8',
#                                'divisionRoadRank': '8',
#                                'gamesPlayed': 69,
#                                'goalsAgainst': 242,
#                                'goalsScored': 182,
#                                'lastUpdated': '2022-04-06T10:39:25Z',
#                                'leagueHomeRank': '30',
#                                'leagueL10Rank': '19',
#                                'leagueRank': '30',
#                                'leagueRecord': {'losses': 41,
#                                                 'ot': 6,
#                                                 'type': 'league',
#                                                 'wins': 22},
#                                'leagueRoadRank': '29',
#                                'points': 50,
#                                'pointsPercentage': 0.36231884057971014,
#                                'ppConferenceRank': '15',
#                                'ppDivisionRank': '8',
#                                'ppLeagueRank': '30',
#                                'records': {'conferenceRecords': [{'losses': 13,
#                                                                   'ot': 6,
#                                                                   'type': 'Eastern',
#                                                                   'wins': 11},
#                                                                  {'losses': 28,
#                                                                   'ot': 0,
#                                                                   'type': 'Western',
#                                                                   'wins': 11}],
#                                            'divisionRecords': [{'losses': 12,
#                                                                 'ot': 0,
#                                                                 'type': 'Central',
#                                                                 'wins': 6},
#                                                                {'losses': 5,
#                                                                 'ot': 3,
#                                                                 'type': 'Atlantic',
#                                                                 'wins': 7},
#                                                                {'losses': 16,
#                                                                 'ot': 0,
#                                                                 'type': 'Pacific',
#                                                                 'wins': 5},
#                                                                {'losses': 8,
#                                                                 'ot': 3,
#                                                                 'type': 'Metropolitan',
#                                                                 'wins': 4}],
#                                            'overallRecords': [{'losses': 20,
#                                                                'ot': 3,
#                                                                'type': 'home',
#                                                                'wins': 12},
#                                                               {'losses': 21,
#                                                                'ot': 3,
#                                                                'type': 'away',
#                                                                'wins': 10},
#                                                               {'losses': 1,
#                                                                'type': 'shootOuts',
#                                                                'wins': 2},
#                                                               {'losses': 4,
#                                                                'ot': 1,
#                                                                'type': 'lastTen',
#                                                                'wins': 5}]},
#                                'regulationWins': 19,
#                                'row': 20,
#                                'streak': {'streakCode': 'W1',
#                                           'streakNumber': 1,
#                                           'streakType': 'wins'},
#                                'team': {'id': 55,
#                                         'link': '/api/v1/teams/55',
#                                         'name': 'Seattle Kraken'},
#                                'wildCardRank': '9'}]}]}

# %%
#finding variables in hockey_json
#name of team
team_name = hockey_json['records'][0]['teamRecords'][0]['team']['name']

#name of Division
team_division = hockey_json['records'][0]['division']['name']

#name of Conference
team_conference = hockey_json['records'][0]['conference']['name']

#name of league
team_league = hockey_json['records'][0]['league']['name']

#number of games played "gp"
team_gp = hockey_json['records'][0]['teamRecords'][0]['gamesPlayed']

#number of wins "W"
team_W = hockey_json['records'][0]['teamRecords'][0]['leagueRecord']['wins']

#number of losses "L"
team_L = hockey_json['records'][0]['teamRecords'][0]['leagueRecord']['losses']

#number of overtime losses "QTL"
team_QTL = hockey_json['records'][0]['teamRecords'][0]['leagueRecord']['ot']

#number of points overall "Pts"
team_Pts = hockey_json['records'][0]['teamRecords'][0]['points']

#number of total goals scored by the team "GF"
team_GF = hockey_json['records'][0]['teamRecords'][0]['goalsScored']

#number of total goals allowed by the team "GA"
team_GA = hockey_json['records'][0]['teamRecords'][0]['goalsAgainst']

#goal differential "diff"
team_diff = team_GF - team_GA

#win loss in last ten games "L10"
team_L10_w = hockey_json['records'][0]['teamRecords'][0]['records']['overallRecords'][3]['wins']
team_L10_l = hockey_json['records'][0]['teamRecords'][0]['records']['overallRecords'][3]['losses']
team_L10_o = hockey_json['records'][0]['teamRecords'][0]['records']['overallRecords'][3]['ot']
team_L10 = f"{team_L10_w}-{team_L10_l}-{team_L10_o}"

#game streak "strk"
team_strk = hockey_json['records'][0]['teamRecords'][0]['streak']['streakCode']


#empty dataframe
test_df = pd.DataFrame(columns=('Team','Conference','Division','League','GP','W','L','QTL','Pts','GF','GA','Diff','L10','Strk'))

test = {'Team' : team_name,
           'Division':team_division,
           'Conference':team_conference,
           'League':team_league,
           'GP': team_gp,
           'W': team_W,
           'L': team_L,
           'QTL': team_QTL,
           'Pts': team_Pts,
           'GF': team_GF,
           'GA': team_GA,
           'Diff': team_diff,
           'L10': team_L10,
           'Strk': team_strk}

test_df = test_df.append(test,ignore_index=True)

test_df.head()
# Out:
#                   Team Conference      Division                  League  GP  \
# 0  Carolina Hurricanes    Eastern  Metropolitan  National Hockey League  70
#
#     W   L QTL Pts   GF   GA Diff    L10 Strk
# 0  45  17   8  98  232  168   64  4-3-3   L2

# %%
test = hockey_json['records'][]
pprint(test)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22312/3219258216.py in <module>
# ----> 1 test = hockey_json['records'][4]
#       2 pprint(test)
#
# IndexError: list index out of range

# %%
# building loops to get info on all teams
x=0
y=0

current_stat_df=pd.DataFrame(columns=('Team','Conference','Division','GP','W','L','QTL','Pts','GF','GA','Diff','L10','Strk'))

x_max = len(hockey_json['records'])

while x < x_max:
    y = 0  
    y_max = len(hockey_json['records'][x]['teamRecords'])
    while y < y_max:
        team_name = hockey_json['records'][x]['teamRecords'][y]['team']['name']
        team_division = hockey_json['records'][x]['division']['name']
        team_conference = hockey_json['records'][x]['conference']['name']
        team_gp = hockey_json['records'][x]['teamRecords'][y]['gamesPlayed']
        team_W = hockey_json['records'][x]['teamRecords'][y]['leagueRecord']['wins']
        team_L = hockey_json['records'][x]['teamRecords'][y]['leagueRecord']['losses']
        team_QTL = hockey_json['records'][x]['teamRecords'][y]['leagueRecord']['ot']
        team_Pts = hockey_json['records'][x]['teamRecords'][y]['points']
        team_GF = hockey_json['records'][x]['teamRecords'][y]['goalsScored']
        team_GA = hockey_json['records'][x]['teamRecords'][y]['goalsAgainst']
        
        team = {'Team' : team_name,
           'Division':team_division,
           'Conference':team_conference,
           'GP': team_gp,
           'W': team_W,
           'L': team_L,
           'QTL': team_QTL,
           'Pts': team_Pts,
           'GF': team_GF,
           'GA': team_GA,
           'Diff': team_diff,
           'L10': team_L10,
           'Strk': team_strk}
        
        current_stat_df = current_stat_df.append(team,ignore_index=True)
        y = y + 1
    x = x + 1

current_stat_df
# Out:
#                      Team Conference      Division  GP   W   L QTL  Pts   GF  \
# 0   Carolina Hurricanes    Eastern    Metropolitan  70  45  17  8   98   232
# 1   New York Rangers       Eastern    Metropolitan  71  45  20  6   96   217
# 2   Pittsburgh Penguins    Eastern    Metropolitan  71  41  20  10  92   237
# 3   Washington Capitals    Eastern    Metropolitan  69  37  22  10  84   226
# 4   New York Islanders     Eastern    Metropolitan  69  32  28  9   73   192
# 5   Columbus Blue Jackets  Eastern    Metropolitan  71  33  32  6   72   229
# 6   Philadelphia Flyers    Eastern    Metropolitan  70  22  37  11  55   181
# 7   New Jersey Devils      Eastern    Metropolitan  70  24  40  6   54   214
# 8   Florida Panthers       Eastern    Atlantic      70  49  15  6   104  294
# 9   Toronto Maple Leafs    Eastern    Atlantic      70  45  19  6   96   270
# 10  Tampa Bay Lightning    Eastern    Atlantic      69  43  19  7   93   230
# 11  Boston Bruins          Eastern    Atlantic      70  44  21  5   93   223
# 12  Detroit Red Wings      Eastern    Atlantic      70  27  34  9   63   202
# 13  Buffalo Sabres         Eastern    Atlantic      71  26  34  11  63   197
# 14  Ottawa Senators        Eastern    Atlantic      69  26  37  6   58   187
# 15  Montréal Canadiens     Eastern    Atlantic      70  19  40  11  49   181
# 16  Colorado Avalanche     Western    Central       70  50  14  6   106  268
# 17  Minnesota Wild         Western    Central       69  43  21  5   91   254
# 18  St. Louis Blues        Western    Central       69  39  20  10  88   250
# 19  Nashville Predators    Western    Central       69  40  25  4   84   230
# 20  Dallas Stars           Western    Central       69  40  26  3   83   204
# 21  Winnipeg Jets          Western    Central       70  33  27  10  76   217
# 22  Chicago Blackhawks     Western    Central       70  24  35  11  59   188
# 23  Arizona Coyotes        Western    Central       70  22  43  5   49   177
# 24  Calgary Flames         Western    Pacific       69  41  19  9   91   241
# 25  Edmonton Oilers        Western    Pacific       71  41  25  5   87   251
# 26  Los Angeles Kings      Western    Pacific       72  38  24  10  86   207
# 27  Vegas Golden Knights   Western    Pacific       71  39  28  4   82   227
# 28  Vancouver Canucks      Western    Pacific       70  32  28  10  74   198
# 29  Anaheim Ducks          Western    Pacific       71  28  31  12  68   199
# 30  San Jose Sharks        Western    Pacific       69  29  31  9   67   182
# 31  Seattle Kraken         Western    Pacific       69  22  41  6   50   182
#
#      GA Diff    L10 Strk
# 0   168  64   4-3-3  L2
# 1   186  64   4-3-3  L2
# 2   194  64   4-3-3  L2
# 3   202  64   4-3-3  L2
# 4   189  64   4-3-3  L2
# 5   265  64   4-3-3  L2
# 6   250  64   4-3-3  L2
# 7   261  64   4-3-3  L2
# 8   210  64   4-3-3  L2
# 9   216  64   4-3-3  L2
# 10  198  64   4-3-3  L2
# 11  190  64   4-3-3  L2
# 12  271  64   4-3-3  L2
# 13  250  64   4-3-3  L2
# 14  224  64   4-3-3  L2
# 15  268  64   4-3-3  L2
# 16  193  64   4-3-3  L2
# 17  215  64   4-3-3  L2
# 18  202  64   4-3-3  L2
# 19  201  64   4-3-3  L2
# 20  206  64   4-3-3  L2
# 21  219  64   4-3-3  L2
# 22  247  64   4-3-3  L2
# 23  254  64   4-3-3  L2
# 24  173  64   4-3-3  L2
# 25  226  64   4-3-3  L2
# 26  205  64   4-3-3  L2
# 27  210  64   4-3-3  L2
# 28  202  64   4-3-3  L2
# 29  230  64   4-3-3  L2
# 30  220  64   4-3-3  L2
# 31  242  64   4-3-3  L2
